# %% [markdown]
# <div style="font-weight:500;font-size:20px;text-align:center;">Hello we will learn Now Seaborn Lib..😍😍</div>

# %% [markdown]
# <div style="font-weight:500;font-size:50px;text-align:center;">Seaborn Lib..😍😍</div>

# %% [markdown]
# 👇🏻👇🏻👇🏻import this buddy to work with Seaborn_lib

# %%
import matplotlib.pyplot as plt
import seaborn as sn

# %%
new = [0,1,2,3,4,5,6,7]
sn.displot(new)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# $Plotting.a.Displot.without.Histogram$

# %%
new = [1,2,3,4,5,6,7,8]
sn.distplot(new , hist = True)
plt.show()


sn.distplot(new , hist = False)
plt.show()
# Out:
# C:\Users\goyam\AppData\Local\Temp\ipykernel_17664\1732034794.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(new , hist = True)
# C:\Users\goyam\AppData\Local\Temp\ipykernel_17664\1732034794.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# Normal Distrubution

# %%
from numpy import random
# generating random array in the normal distribution
x = random.normal(size =(2,3))
x
# Out:
# array([[-0.15381489, -0.97206946, -0.00133028],
#        [ 0.31172772,  0.6489806 , -0.92483562]])

# %%
x = random.normal(loc=1,scale= 2,size =(2,3))
x
# Out:
# array([[-0.22525923,  2.00346577,  0.81287901],
#        [-2.49842059,  3.21096368,  0.00638853]])

# %% [markdown]
# Visualization of Normal Distribution

# %% [markdown]
# Note: The curve of a Normal Distribution is also known as the Bell Curve because of the bell-shaped curve.

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.normal(size=1000),hist = False)
plt.show()
# Out:
# C:\Users\goyam\AppData\Local\Temp\ipykernel_17664\53749331.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size=1000),hist = False)

# %% [markdown]
# $Binomal.Distribution$ <br>
# Discreate Distribution

# %%
from numpy import random
x = random.binomial(n=10, p=0.5,size=10)

x
# Out:
# array([7, 4, 5, 2, 4, 5, 3, 3, 6, 4])

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sn

x = random.binomial(n=10, p=0.5,size=1000)


sn.distplot(x,hist= True,kde=True)
plt.show()
# Out:
# C:\Users\goyam\AppData\Local\Temp\ipykernel_14448\1383085054.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(x,hist= True,kde=True)

# %% [markdown]
# Difference between Normal and Binomal Distribution

# %%
from cProfile import label
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(random.normal(loc=50,scale=5,size=1000),hist = False,label='normal')

sns.distplot(random.binomial(n=100,p=0.5,size=1000),hist = False,label='binomal')
plt.show()
# Out:
# C:\Users\goyam\AppData\Local\Temp\ipykernel_14448\2428302102.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(loc=50,scale=5,size=1000),hist = False,label='normal')
# C:\Users\goyam\AppData\Local\Temp\ipykernel_14448\2428302102.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# <span style="font-size:30px;color:lightblue;">Poisson Distribution</span> <br>
# $Discrete Distribution$

# %%
from numpy import random
x = random.poisson(lam=2,size=10)
x
# Out:
# array([0, 3, 1, 0, 1, 0, 3, 7, 4, 5])

# %% [markdown]
# Visualization of Poisson Distribution

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
x = random.poisson(lam=2,size=1000)

sns.distplot(x,kde=False)
plt.show()
# Out:
# C:\Users\goyam\AppData\Local\Temp\ipykernel_14448\3720061353.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x,kde=False)

# %% [markdown]
# <span style="font-size:25px;">Difference Between Normal and Poisson Distribution</span>
# <br>
# <span style="font-size:15px;">Normal distribution is continuous whereas poisson is discrete</span>
